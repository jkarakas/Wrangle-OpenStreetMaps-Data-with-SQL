# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

#Imports
import xml.etree.cElementTree as ET  # Use cElementTree or lxml if too slow
from collections import defaultdict
import re
import pprint
import os
import pandas as pd
import urllib, json
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.notebook_repr_html', True)
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# ### Create a smaller version of the map (Warsaw-Poland))

# %%
'''Take a smaller sample of the map for auditing purposes '''

k = 2 # Parameter: take every k-th top level element

OSM_FILE = "warsaw_poland.osm"  # Replace this with your osm file
SAMPLE_FILE = "warsaw_poland_sample_k="+ str(k) + ".osm"


def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>')
    
    #Get the file sizes in Kilobytes
    Original_OSM_size = os.path.getsize(OSM_FILE)/0.001
    Sample_OSM_size = os.path.getsize(SAMPLE_FILE)/0.001
    
    print(' Done \n Original_OSM_size: {:,} KBytes\n Sample_OSM_size: {:,} KBytes'.format(Original_OSM_size, Sample_OSM_size))
# Out:
#  Done
#  Original_OSM_size: 1,169,168.705 KBytes
#  Sample_OSM_size: 592,097.28 KBytes

# %% [markdown]
# ### Find out what kind of tags exist in your file

# %%
def count_tags(filename):
    """
    Use the iterative parsing to process the map file and
    find out what tags are there, but also how many and to get the
    feeling on how much of which data you can expect to have in the map.
    Returns a dictionary with the tag name as the key and number of times this tag can be encountered in 
    the map as value.

    """  
    #init empty dic
    elem_dic = defaultdict(int)
    
    #parse the xml file
    tree = ET.parse(filename)
    
    #get the elements, convert to string and extract the tags
    for elem in tree.iter():
        elem_dic[elem.tag]+=1      
        
    return elem_dic

# %%
osm_file = 'warsaw_poland_sample_k=5.osm'
tags = count_tags(osm_file)
pd.Series(tags).sort_values(ascending=False)
# Out:
# nd          1174493
# node         983267
# tag          897948
# way          126661
# member        36939
# relation       1669
# osm               1
# dtype: int64

# %% [markdown]
# ### Explore attributes

# %%
def count_attribs(filename):
    """
    Use the iterative parsing to process the map file and
    find out what attribs are there, but also how many and to get the
    feeling on how much of which data you can expect to have in the map.
    Returns a pandas dataseries with the tag name as the key and number of times this tag can be encountered in 
    the map as value.

    """  
    #init empty dic
    attrib_dic_tag = defaultdict(int)
    
    #parse the xml file
    # tree =  etree.parse(filename)
   
    #get the elements, convert to string and extract the tags
    for _, element in ET.iterparse(filename):
        if element.tag == "tag":
                attrib_dic_tag[element.attrib['k']]+=1      
        
    return attrib_dic_tag

# %%
attribs = count_attribs(osm_file)

attribs_df = pd.DataFrame({'attribs':attribs.keys(), 'counts': attribs.values()}).sort_values(by='counts', ascending=False)

# %%
attribs_df.head(500)
# Out:
#                                       attribs  counts
# 289                          addr:housenumber  105903
# 851                                 addr:city   93634
# 48                                addr:street   92431
# 596                             addr:postcode   92050
# 513                               source:addr   75741
# 1040                                 building   65054
# 116                            addr:city:simc   58661
# 374                        addr:street:sym_ul   47211
# 377                                   highway   41257
# 827                                    source   39508
# 328                                      name   19951
# 265                                addr:place   13977
# 486                                   landuse   12671
# 751                                   surface    7695
# 375                                       ref    6118
# 260                                   natural    6072
# 143                                   amenity    5690
# 383                                   barrier    5626
# 798                                    oneway    4463
# 2                                    maxspeed    3501
# 49                                    service    3078
# 719                                     lanes    2928
# 365                                   network    2676
# 87                                      power    2475
# 602                          public_transport    2426
# 92                                     access    2193
# 678                                   railway    2179
# 506                                       lit    1909
# 504                           building:levels    1874
# 762                                 emergency    1841
# 1024                        fire_hydrant:type    1756
# 442                                 tracktype    1749
# 171                                      type    1692
# 544                                      shop    1685
# 999                     fire_hydrant:diameter    1602
# 961                                       bus    1583
# 22                                 created_by    1549
# 380                           source:maxspeed    1473
# 338                                  crossing    1470
# 939                                  operator    1468
# 583                                   leisure    1428
# 69                                    bicycle    1382
# 318                                      foot    1313
# 410                           source:geometry    1240
# 634                                 wikipedia    1240
# 498                                  wikidata    1211
# 744                                     layer    1151
# 91                                  leaf_type    1124
# 811                                   voltage    1110
# 641                                  boundary    1053
# 777                     fire_hydrant:position    1002
# 403                              area:highway     963
# 691                                    height     914
# 757                                  waterway     865
# 715                                   website     832
# 557                                     gauge     822
# 415                                     place     816
# 918                                   footway     816
# 388                               electrified     809
# 945                             opening_hours     795
# 13                                   ref:addr     765
# 708                      maxspeed:conditional     712
# 620                                   parking     686
# 943                                      area     683
# 684                                teryt:simc     679
# 760                               maxaxleload     651
# 991                    source:maxaxleload:url     646
# 873                        source:maxaxleload     646
# 349                                 frequency     631
# 490                                    bridge     625
# 107                                     water     585
# 276                             building:part     576
# 175                                  entrance     570
# 710                         building:material     560
# 142                                turn:lanes     508
# 524                           building:colour     508
# 817                                      note     480
# 120                                roof:shape     480
# 184                                     phone     466
# 191                                    tunnel     450
# 341                             roof:material     434
# 188                           traffic_calming     425
# 1028                                  shelter     423
# 823                                  cemetery     422
# 801                              addr:country     422
# 62                                      bench     392
# 305                                  junction     365
# 838                               roof:colour     355
# 890                                  man_made     333
# 502                                     sport     330
# 845                                  historic     330
# 386                                 maxweight     327
# 263                                wheelchair     325
# 284                                   int_ref     312
# 628                                  capacity     302
# 758                                   cuisine     295
# 274                               restriction     293
# 42                              motor_vehicle     286
# 865                                smoothness     275
# 526                             name:genitive     274
# 1007                                   cables     271
# 408                                     route     264
# 958                               admin_level     260
# 833                                     usage     259
# 320                                   tourism     258
# 437                                     horse     253
# 310                                  material     248
# 1032                               min_height     241
# 165                  public_transport:version     238
# 469                                  distance     233
# 301                                   covered     224
# 155                                       fee     218
# 1012                           is_in:province     206
# 948                                     width     206
# 816                        is_in:municipality     202
# 445                              is_in:county     202
# 643                                     email     202
# 869                                  alt_name     199
# 1042                             maxspeed:bus     190
# 470                  maxspeed:hgv:conditional     190
# 820                          maxspeed:trailer     190
# 552                                  old_name     189
# 254                                  teryt:rm     188
# 1037                            teryt:stan_na     185
# 805                                      from     178
# 158                                        to     178
# 1016                                 cycleway     178
# 748                                  backrest     178
# 804                                  proposed     168
# 53                                      level     166
# 72                                roof:height     165
# 966                              construction     164
# 858                               destination     164
# 892                                  religion     163
# 406                                segregated     159
# 325                                     fixme     158
# 385                                fence_type     158
# 534                            tactile_paving     158
# 330                                      tram     154
# 539                       highway:category:pl     149
# 906                          highway:class:pl     149
# 651                              denomination     149
# 79                           teryt:updated_by     147
# 50                                source:name     144
# 56                                   toll:hgv     144
# 514                                  toll:bus     144
# 304                                   old_ref     142
# 592                                   name:en     135
# 446                                  motorcar     134
# 515                             is_in:village     134
# 648                            lanes:backward     134
# 517                             lanes:forward     131
# 947                             contact:phone     131
# 696                                       ele     127
# 404                                    noexit     124
# 443                            addr:housename     117
# 468                                population     116
# 831                                  location     113
# 818                               transformer     113
# 790                                    colour     110
# 275                                    office     108
# 283                                motorcycle     107
# 197                              buildingpart     106
# 313                         source:population     105
# 29                                        fax     102
# 182                                 motorroad     102
# 917                                   incline     102
# 302                           contact:website     102
# 449                                 park_ride     101
# 28          maxgcweightrating:hgv:conditional     100
# 63                                   sidewalk     100
# 577              source:maxgcweightrating:hgv     100
# 923                                supervised      98
# 737                                   note:pl      97
# 561                          trail_visibility      96
# 151                                   name:pl      96
# 257                            ztm:ciąg_ulicy      93
# 525                                 placement      88
# 173                               colour:text      86
# 121                               colour:back      86
# 244                              agricultural      85
# 528                                       url      84
# 1                                colour:arrow      84
# 108                               addr:source      84
# 512                                   towards      83
# 714                           bicycle_parking      83
# 245                               description      83
# 431                              crossing:end      83
# 839                                short_name      82
# 7                          turn:lanes:forward      81
# 962                                     brand      80
# 177                                      door      79
# 1001                            official_name      79
# 185                                     train      77
# 837                                       bin      77
# 14                                      is_in      76
# 988                                dispensing      76
# 849                                       psv      76
# 395                       turn:lanes:backward      76
# 467                               name:prefix      75
# 606                  tactile_paving:slab_size      74
# 488                               roof:levels      74
# 576                      roof:slope:direction      71
# 212                        building:min_level      68
# 409                                       atm      67
# 826                                   name:de      67
# 703                            millennium:ref      67
# 458                           millennium:date      67
# 891                          roof:orientation      67
# 879                              route_master      65
# 336                                embankment      65
# 567                                is_in:city      63
# 717                                 direction      63
# 1021                               denotation      62
# 725                                 maxheight      62
# 883                               step:height      62
# 605                                leaf_cycle      62
# 479                                   aeroway      61
# 285                           source:position      61
# 617                                 lamp_type      60
# 622                                   name:ru      59
# 222                               information      57
# 162                               addr:sector      57
# 854                                   vending      57
# 661                                substation      56
# 451                note:maxgcweightrating:hgv      56
# 312                           source:toll:url      56
# 141                               source:toll      56
# 894                                  addr:row      56
# 1055                         maxspeed:forward      55
# 866                           internet_access      53
# 683                         maxspeed:backward      53
# 47                          railway:track_ref      52
# 996                                       hgv      52
# 439                             protect_class      51
# 649                             contact:email      50
# 570                        millennium:network      49
# 679                          watch:balrog-kun      48
# 327                        millennium:subtype      48
# 1015                             traffic_sign      47
# 477                                   atm_ref      47
# 631                               fuel:diesel      47
# 484                                   wetland      47
# 510                          protection_title      46
# 773                            fuel:octane_95      46
# 730                       protection_title:pl      46
# 727                                   smoking      46
# 775                               advertising      45
# 71                                   fuel:lpg      45
# 787                                     genus      45
# 812                                     seats      44
# 766                            fuel:octane_98      44
# 832                                   bollard      42
# 870                                addr:flats      42
# 977              buildingpart:verticalpassage      41
# 495                  source:maxspeed:backward      40
# 652                   source:maxspeed:forward      40
# 880                           destination:ref      40
# 843   buildingpart:verticalpassage:floorrange      39
# 994                              crossing_ref      38
# 300                         capacity:disabled      38
# 759                                  memorial      36
# 411                              shelter_type      36
# 329                               designation      33
# 685                             drive_through      32
# 94                                       toll      32
# 90                               wikipedia:en      32
# 738                         fire_hydrant:note      32
# 980                           passenger_lines      32
# 724                                     craft      31
# 270                                  takeaway      31
# 899                              artwork_type      31
# 765                              surveillance      30
# 448                                       gid      30
# 586                                kodinspire      30
# 659                                board_type      29
# 41                                    name:uk      29
# 109                                    tracks      29
# 401                                teryt:terc      29
# 26                           crossing:barrier      29
# 623                     traffic_signals:sound      29
# 709                                 teryt:typ      29
# 262                            crossing:light      27
# 30                                     indoor      27
# 154                               osmc:symbol      27
# 472                            name:adjective      27
# 692                                      pole      26
# 168                                   vehicle      26
# 969                                 lanes:psv      25
# 424                                 sac_scale      25
# 970                                      line      25
# 568                                     state      24
# 76                                     design      24
# 697                         destination:lanes      24
# 794                                      boat      23
# 935                                 mtb:scale      22
# 238                                    animal      22
# 667                                   country      21
# 1059                          alt_addr:street      21
# 178                                  end_date      21
# 953                              is_in:suburb      21
# 934                                     image      21
# 973                                teryt:ulic      21
# 522                           fuel:HGV_diesel      20
# 776                                     wires      20
# 15                            building:height      20
# 613                                  int_name      20
# 579                                   name:lt      20
# 489                         maxgcweightrating      19
# 559                           capacity:parent      19
# 779                              payment:visa      19
# 61                                     noname      19
# 824                   maxgcweight:conditional      18
# 808                             old_addr:city      18
# 389                         millennium:usługi      18
# 673                            cycleway:right      18
# 148                                tower:type      18
# 688                                      wall      18
# 795                                   cutting      18
# 358                                  loc_name      17
# 609                                   name:es      17
# 1030                                   symbol      17
# 65                                    disused      16
# 337                        source:maxgcweight      16
# 963                                      ford      16
# 213                            building:level      16
# 857                              camera:mount      16
# 700                                nest_mount      16
# 886                                birds_nest      16
# 601                       internet_access:fee      16
# 981                               maxgcweight      16
# 474                                diplomatic      16
# 689                             nest_platform      15
# 172                                start_date      15
# 482                              area:size:ha      15
# 183                            capacity:women      15
# 665                            street_cabinet      15
# 140                         surveillance:type      15
# 908                        railway:signal_box      14
# 21                                  SITE_CODE      14
# 295                  source:maxgcweightrating      14
# 680                       paving_stones:shape      14
# 466                             crossing:bell      14
# 997                                 psv:lanes      14
# 698                         surveillance:zone      14
# 280                              payment:cash      14
# 1045                              established      14
# 527                             payment:coins      14
# 964                                  delivery      14
# 735                                   deanery      13
# 836                                       ski      13
# 309                                      died      13
# 706                            reservoir_type      13
# 593                               contact:fax      13
# 18                               seamark:type      13
# 242                                     FIXME      13
# 582                               routing:ztm      13
# 509                                      born      13
# 297                                attraction      12
# 859                                 highspeed      12
# 455                                  heritage      12
# 203                               inscription      12
# 780                                    levels      12
# 1058                        heritage:operator      12
# 871                                   diocese      12
# 491                        addr:interpolation      12
# 572                                is_in:town      12
# 453                               camera:type      12
# 335                               source:user      12
# 60                                     subway      11
# 372                                playground      11
# 1009                           recycling_type      11
# 716                          historic:service      11
# 903                             cycleway:left      11
# 85                             historic:gauge      11
# 326                                      odbl      11
# 264                           outdoor_seating      11
# 538                             surface:grade      11
# 331                                   ref:nid      11
# 236                                   name:fr      11
# 928                                      tomb      11
# 615                                  map_size      11
# 17                               teryt:sympod      11
# 225                                      room      11
# 922                            roof:direction      11
# 915                                     goods      11
# 219                                   species      11
# 952                                     stars      10
# 413                           button_operated      10
# 949                     destination:ref:lanes      10
# 208                       location:transition      10
# 976                            oneway:bicycle      10
# 627                               railway:ref      10
# 781                          source:maxweight      10
# 27                           camera:direction      10
# 853                              disused:shop      10
# 319                                  map_type      10
# 713                                snowmobile      10
# 221                      historic:electrified      10
# 591                                   name:eo       9
# 1047                                     wifi       9
# 340                                      kerb       9
# 835             maxspeed:backward:conditional       9
# 642                  destination:colour:lanes       9
# 656                              building:use       9
# 632              maxspeed:forward:conditional       9
# 929                                step_count       8
# 422                           recycling:glass       8
# 752                               sloped_curb       8
# 138                                    hiking       8
# 662                                species:pl       8
# 5                         destination:forward       8
# 189                                   uic_ref       8
# 907                 traffic_signals:vibration       8
# 190                           fuel:GTL_diesel       8
# 1022                             self_service       8
# 905                          construction_end       8
# 896                           fuel:octane_100       8
# 359                          mtb:scale:uphill       7
# 537                  destination:symbol:lanes       7
# 59                                   genus:pl       7
# 77                                    name:it       7
# 66                            recycling:paper       7
# 742                                overtaking       7
# 298                  disused:public_transport       7
# 322                         wikimedia_commons       7
# 840                            fuel:biodiesel       7
# 492                               enforcement       7
# 888                                  3dr:type       7
# 416                               second_hand       7
# 163                           disused:highway       7
# 901                     maxspeed:bus:backward       6
# 134                                   name:pt       6
# 303         maxspeed:hgv:backward:conditional       6
# 290                                       hov       6
# 982                                teryt:name       6
# 770                               lanes:extra       6
# 417                        toilets:wheelchair       6
# 57                                region_type       6
# 100                 destination:int_ref:lanes       6
# 860                                   mooring       6
# 136                                  handrail       6
# 874                      destination:backward       6
# 932                           old_addr:street       6
# 174                           region_category       6
# 930                                    repair       6
# 855                        vehicle_plate_code       6
# 971                 maxspeed:trailer:backward       6
# 299                                 fuel:1_25       5
# 619                                 route_ref       5
# 494                            mtb:scale:imba       5
# 500                          fuel:electricity       5
# 55                           bridge:structure       5
# 965                           social_facility       5
# 1025                                  name:nl       5
# 31          maxgvweightrating:hgv:conditional       5
# 1043                traffic_signals:direction       5
# 533               building:levels:underground       5
# 540                           disused:railway       5
# 541                       destination:int_ref       5
# 1049                          traffic_signals       5
# 545                                    rating       5
# 4                                currency:PLN       5
# 633                                roof:angle       5
# 428                         parking:lane:both       5
# 463                                 fuel:1_50       5
# 936                            ruins:building       5
# 711                               disused:ref       5
# 875                                 platforms       5
# 371                      maxspeed:bus:forward       5
# 862                                     tower       5
# 193                  maxspeed:trailer:forward       5
# 390          maxspeed:hgv:forward:conditional       5
# 216                                   station       5
# 736                    railway:local_operated       5
# 739                               fuel:biogas       5
# 147                                     color       5
# 226                                      turn       5
# 419                   railway:switch:electric       5
# 635                          note:maxgcweight       5
# 202                                   history       5
# 768                                ref:source       5
# 771                            fuel:octane_91       5
# 786                        parking:lane:right       5
# 456                               artist_name       5
# 645                          electrified:rail       5
# 266                                  fuel:cng       5
# 809                                   name:cs       4
# 307                                source:ref       4
# 555                       payment:debit_cards       4
# 32                    seamark:notice:function       4
# 519                fire_hydrant:coupling_type       4
# 521                              maxspeed:hgv       4
# 6                      fire_hydrant:couplings       4
# 355                               old_int_ref       4
# 1052                           level_crossing       4
# 11                 note:maxgvweightrating:hgv       4
# 317                                 milestone       4
# 578                                   name:lv       4
# 847                                       lcn       4

# %%
attribs_df[attribs_df.attribs.str.contains('amenity',case=False)]
# Out:
#                  attribs  counts
# 143              amenity    5690
# 877      disused:amenity       3
# 399          old_amenity       3
# 1003  ata_delete:amenity       1

# %%
#Find Function
def find(filename, attrib_type):
    '''Receives OSM filename and the attribute type the k element
    and returns a dictionary with keys the attribute types and values their count of occurence'''
    types = defaultdict(int)
    for _, element in ET.iterparse(filename):
        try:
            if element.attrib['k'] == attrib_type:
                types[element.attrib['v']]+=1
        except:
            continue
    return types

# %%
#Find phone
osm_file = 'warsaw_poland_sample_k=5.osm'
types = find(osm_file, 'phone')

phone = pd.DataFrame({'val':types.keys(), 'counts': types.values()}, columns=['val','counts']).sort_values(by='counts', ascending=False)

# %%
phone[phone.val.str.contains('',case=False)]
# Out:
#                                                    val  counts
# 463                                       22 664 21 00       2
# 310                                          501139027       2
# 305                                   +48 22 418 00 00       1
# 317                                    +48 517 127 167       1
# 316                                   +48 22 641 93 03       1
# 315                                     +48 22 3532266       1
# 314                                       +48226486630       1
# 313                               226211646, 601243466       1
# 312                                   +48 25 759 51 00       1
# 311                                   +48 22 627 11 00       1
# 309                                       +48227221088       1
# 308                                          228410441       1
# 307                                   +48 22 678 17 17       1
# 306                                          223539999       1
# 304                                    +48 261 855 690       1
# 1                                         22 845 05 71       1
# 303                                   +48 22 857 34 90       1
# 302                                   +48 46 855 35 47       1
# 301                                     +48 22 6037655       1
# 300                                      +48 228773806       1
# 299                                       +48227762001       1
# 298                                      +48 226310504       1
# 297                                     +48 22 2791400       1
# 296                                   +48 25 757 11 79       1
# 295                                   +48 22 826 30 95       1
# 294                                     +48 22 2578499       1
# 293                                   +48 22 569 71 57       1
# 292                                       +48226121616       1
# 318                               228225799, 228222005       1
# 319                                       +48501728895       1
# 320                                     +22 7673107-08       1
# 321                                    +48 503 086 515       1
# 346                                   +48 22 245 30 32       1
# 345                                       22 774 45 14       1
# 344                                    +48 508 954 164       1
# 343                                       22 664 07 28       1
# 342                                       +48468564092       1
# 341                                       +48602326874       1
# 340                     +4822 849 14 56;+4822848 48 09       1
# 339                                       +48226145460       1
# 338                                    +48 504 799 161       1
# 337                                          694000009       1
# 336                                       22 664 40 49       1
# 335                                     +48 22 6149030       1
# 334                                       22 616 54 00       1
# 333                                         22 8100782       1
# 332                                   +48 22 611 88 88       1
# 331                                          531534904       1
# 330                                          660341255       1
# 329                                   +48 22 825 52 21       1
# 328                                   +48 22 544-26-00       1
# 327                                       +48224582444       1
# 326                                       22 632 19 18       1
# 325                          +48226171585;+48226174293       1
# 324                                    +48 603 894 843       1
# 323                                          509857864       1
# 322                  +48 22 750 02 12; +48 506 147 417       1
# 291                                         22 8771300       1
# 290  +48 22 737 70 70; +48 22 737 71 59; +48 22 703...       1
# 289                                   +48 22 716 51 00       1
# 260                                   +48 46 895 53 19       1
# 258                                       +48227871440       1
# 257                                   +48 22 416 26 11       1
# 256                                     +48 22 3929700       1
# 255                                         22 6125819       1
# 254                                       +48504949689       1
# 253                                   +48 22 353 20 20       1
# 252                                          228460942       1
# 251                                   +48 22 355 70 00       1
# 250                                       22 50 68 100       1
# 249                                       +48227838888       1
# 248                                    +48 693 415 549       1
# 247                                       +48227308100       1
# 246                                       25 752 08 26       1
# 245                                       +48503753942       1
# 244                                          228389201       1
# 243                          +48227625365;+48510185277       1
# 242                                          226767134       1
# 241                                       22 436 50 01       1
# 240                                   +48 22 849 35 73       1
# 239                                       22 334 86 00       1
# 238                                       22 114 90 90       1
# 237                                    +48 794 265 385       1
# 236                                   +48 22 675 01 50       1
# 235                                   +48 22 839 04 20       1
# 234                                       22 451 40 29       1
# 259                         504 019 090, 022 772 61 67       1
# 261                                   +48 46 856 30 30       1
# 288                                   +48 22 592 85 83       1
# 262                                   +48 22 782 30 77       1
# 287                                       +48227867279       1
# 286                                   +48 25 75 75 693       1
# 285                                     +48 22 7567236       1
# 284                                     +48 22 8944200       1
# 283                                       +48227028777       1
# 282                                   +48 25 759 67 15       1
# 281                                       22 767 53 80       1
# 280                                        504 915 178       1
# 279                                     +48 22 5190000       1
# 278                                       22 342 92 50       1
# 277                                        600 015 902       1
# 276                                       +48226182102       1
# 275                                   +48 46 857 13 41       1
# 274                                          501455221       1
# 273                                   +48 22 751 93 94       1
# 272                                          501867708       1
# 271                                     +48-22-6141422       1
# 270                                         0000231936       1
# 269                  +48 801 412 414, +48 22 737 50 50       1
# 268                                       22 299 28 71       1
# 267                                   +48 22 610 73 09       1
# 266                                     +48 22 7837110       1
# 265                                   +48 22 825 16 50       1
# 264                                  + 48 22 725 45 61       1
# 263                                       +48227570840       1
# 347                                       22 625 04 96       1
# 348                                   +48 25 758 28 14       1
# 349                                   +48 22 514 05 30       1
# 435                                    +48 784 335 558       1
# 433                                       22 845 03 28       1
# 432                                       +48788451799       1
# 431                                    +48 663 143 520       1
# 430                                    +48 784 051 110       1
# 429                                    +48 782 755 544       1
# 428                                   +48 22 736 29 00       1
# 427                                     +48 22 8115977       1
# 426                                   +48 22 773 32 81       1
# 425       +48 22 8842080;+48 22 8842081;+48 22 8842082       1
# 424             +48224984646;+48224982626;+48224997764       1
# 423                                   +48 22 403 50 77       1
# 422                                         22 8143316       1
# 421                                       +48226356314       1
# 420                                       22 666 44 50       1
# 419                                   +48 22 448 36 76       1
# 418                                   +48 22 473 59 90       1
# 417                                     +48 22 7742673       1
# 416                                          225512040       1
# 415    +4822 39 27 112;+4822 39 27 113;+4822 39 27 111       1
# 414                               792000088, 792000099       1
# 413                                       22 826 14 48       1
# 412                                     (22) 693 50 00       1
# 411                                   +48 22 11 000 84       1
# 410                                    +48 608 502 017       1
# 409                                     +48 22 8220920       1
# 434                                   +48 22 415 00 99       1
# 436                                        533-733-033       1
# 407                                       +48227540650       1
# 437                                   +48 22 784 45 41       1
# 462                                          226294071       1
# 461                                       +48226280295       1
# 460                                    +48 506 852 222       1
# 459                                    +48 510 233 032       1
# 458                                       22 53 37 647       1
# 457                                   +48 23 691 04 87       1
# 456                                   +48 22 244 13 13       1
# 455                                    +48 728 639 639       1
# 454                                   +48 22 646 58 55       1
# 453                  +48 607 383 353; +48 22 750 26 28       1
# 452                                       22 643 20 33       1
# 451                                       +48225133670       1
# 450                            +48226768287;+226767737       1
# 449                                   +48 22 774 43 44       1
# 448                                   +48 22 737 67 97       1
# 447                                       +48224035555       1
# 446                                   +48 25 759 97 30       1
# 445                 +48 22 464 84 40, +48 506 18 24 99       1
# 444                                       +48225361300       1
# 443                                          501600503       1
# 442                                     +48 22 7679311       1
# 441                                       22 833 87 88       1
# 440                  +48 22 649 25 63, +48 505 129 270       1
# 439                                   +48 22 205 81 21       1
# 438                                   +48 22 205 81 22       1
# 408                                    +48 501 516 009       1
# 406                                       +48257593643       1
# 350                                         22 2152600       1
# 377                                   +48 22 843 58 35       1
# 375                                   +48 22 863 92 52       1
# 374            (22) 614-31-95;603-85-31-95;609-216-946       1
# 373                                   +48 22 611 70 35       1
# 372                                   +48 22 115 05 05       1
# 371                                    +48 261 842 075       1
# 370                                   +48 22 462 85 20       1
# 369                                         22 8373252       1
# 368                                      +48 505019290       1
# 367                                       +48225721800       1
# 366                                   +48 22 777 62 11       1
# 365                                       +48227231444       1
# 364                                        603 274 226       1
# 363                                   +48 22 810 33 84       1
# 362                                       22 101 19 42       1
# 361                                          226434797       1
# 360                                   +48 22 782 71 08       1
# 359                                    +48 518 130 434       1
# 358                                       +48226293576       1
# 357                                   +48 22 436 56 03       1
# 356                                      +48 225827500       1
# 355                                       +48468578260       1
# 354                                    +48 601 232 962       1
# 353                                          507015736       1
# 352                                       22 774 11 22       1
# 351                                       +48226108503       1
# 376                                       +48228720583       1
# 378                                   +48 22 611 34 19       1
# 405                                   +48 22 732 00 36       1
# 379                                          226323191       1
# 404                    486642726; 512217853; 798547093       1
# 403                                   +48 22 531 60 00       1
# 402                                     +48 22 8260363       1
# 401                          +48222560156;+48661433324       1
# 400                                       +48226240800       1
# 399                                   +48 22 373 37 00       1
# 398                  +48 22 501 53 11;+ 48 533 388 588       1
# 397                                          228168001       1
# 396                                       +48690693093       1
# 395                                    +48 501 190 009       1
# 394                                   +48 535 04 50 50       1
# 393                                          536221878       1
# 392                                    +48  22 2113232       1
# 391                           22825 17 85, 22825 68 09       1
# 390                                       22 767 91 11       1
# 389                                       +48227856583       1
# 388                                      0048662254215       1
# 387                                    +4822 651 60 98       1
# 386                                   +48 22 123 76 78       1
# 385                                      +48 607552069       1
# 384                                   +48 22 773 61 30       1
# 383                      +4822628 63 30;+4822628 25 86       1
# 382                                    +48 888 942 999       1
# 381                                       22 831 32 00       1
# 380                                       22 697 88 50       1
# 233                                          226416356       1
# 0                                          22836 48 38       1
# 231                                   +48 603 99 66 66       1
# 86                                        +48227811817       1
# 84                                           663830020       1
# 83                                        +48722311722       1
# 82                                           228110744       1
# 81                                      +48 22 5722500       1
# 80                                        +48224978567       1
# 79                                        +48222176500       1
# 78                                    +48 22 462 83 10       1
# 77                                           226634849       1
# 76   +48228263471;+48228263472;+48228263473;+482282...       1
# 75                                          22 8311760       1
# 74                                   +48 22 77 33 77 9       1
# 73                                         601 158 223       1
# 72                                    +48 23 691 05 50       1
# 71                                        +48226794692       1
# 70                                       +48 226215315       1
# 69                                        +48224902025       1
# 68                                        +48224635201       1
# 67                                     +48 506 666 118       1
# 66                                      +48 22 3496100       1
# 65                                    +48 22 487 98 91       1
# 64                                        +48228266318       1
# 63                                        +48228348668       1
# 62                                        +48228112962       1
# 61                                       0048227555061       1
# 60                                    +48 785 81 82 82       1
# 85                                          22 8366662       1
# 87                                        22 721 21 00       1
# 58                                        48 370 38 97       1
# 88                                   +48 023 691 04 27       1
# 113                                    +48 881 406 406       1
# 112                                   +48 22 649 14 40       1
# 111                                       22 614 22 50       1
# 110                                       +48693077633       1
# 109                                       22 773 29 87       1
# 108                                   +48 25 757 78 93       1
# 107                                   +48 22 258 39 59       1
# 106                                   +48 48 661 43 37       1
# 105                                          228381994       1
# 104                                   +48 22 88 777 37       1
# 103                                    +48 797 901 201       1
# 102                                   +48 22 217 31 20       1
# 101                                       +48227284262       1
# 100             +48228895012;+48228895013;+48226765380       1
# 99                          22 831 16 83, 22 831 54 51       1
# 98                               22 8897080, 228897081       1
# 97                                        22 828 12 82       1
# 96                                    +48 22 649 99 81       1
# 95                       +4822629 34 46;+4822622 47 97       1
# 94                                    +48 22 405 82 90       1
# 93                                         502 121 330       1
# 92                                    +48 22 407 20 03       1
# 91                                        +48226141190       1
# 90                                        +48226489818       1
# 89                           22 889 00 57, 508 911 626       1
# 59                                      +48 22 7568056       1
# 57                       +48 22 6203394;+48 22 6202785       1
# 115                         22 300 40 44, 606 44 66 56       1
# 28                                     +48 503 493 778       1
# 26                                     +48 22 558 1234       1
# 25                                           228361125       1
# 24                                           228844610       1
# 23                                226640699, 226641098       1
# 22                                        48 664 34 94       1
# 21                                        22 877 21 25       1
# 20                                    +48 22 812 65 17       1
# 19                                        +48500021342       1
# 18                                    +48 22 833 56 60       1
# 17   +48226253410;+48226253368;+48226221350;+482262...       1
# 16                                    +48 22 51 66 100       1
# 15                                        22 831 76 92       1
# 14              +48226213453;+48226215575;+48226215954       1
# 13                                          22 6139344       1
# 12                                    +48 22 349 23 96       1
# 11                                        +48501040903       1
# 10                        +48 22 6143866;+48 501040780       1
# 9                                         22 244 13 60       1
# 8                                     +48 22 825 36 70       1
# 7                                       +48 22 6142239       1
# 6                                         +48227534010       1
# 5                                     +48 22 810 02 57       1
# 4                                        +48 728827546       1
# 3                                     +48 22 408 20 20       1
# 2                                            609050512       1
# 27                                        +48515038839       1
# 29                                        +48227836604       1
# 56                                        +48227231252       1
# 30                                     +48 261 879 505       1
# 55                                        22 723 94 28       1
# 54                                    +48 22 582 99 00       1
# 53                                        22 441 91 36       1
# 52                                        22 343 03 00       1
# 51                                      +48 22 4033442       1
# 50                                        +48506859954       1
# 49                                        22 499 00 80       1
# 48                                    +48 22 813 10 22       1
# 47                                        +48226120023       1
# 46                                           225194960       1
# 45                                         504 180 800       1
# 44                                       +48 886886856       1
# 43                                    +48 22 756 22 18       1
# 42                           22 64 65 687, 601 800 190       1
# 41                                    +48 519 00 00 14       1
# 40                                   (+48) 516-252-390       1
# 39                                        +48501701442       1
# 38                                        +48570600507       1
# 37                                        +48226490503       1
# 36                                         502 361 078       1
# 35                                      (25) 752-70-06       1
# 34                                           226759866       1
# 33                                     +48 789 495 410       1
# 32                                    +48 22 44 30 400       1
# 31                                        22 758 57 95       1
# 114                                   (+48) 22 7581643       1
# 116                          23 661 33 91; 500 242 605       1
# 230                                   +48 22 844 56 96       1
# 202                                   +48 22 757 00 73       1
# 200                                       +48224259524       1
# 199                                      0048228901605       1
# 198       +4822849 64 14;+4822849 14 06;+4822849 47 30       1
# 197                                      +48 228142179       1
# 196                                   +48 22 679 84 69       1
# 195                                   +48 22 678 84 76       1
# 194                                     +48-22-6757186       1
# 193                                   +48 22 811 92 84       1
# 192                                          228361474       1
# 191                                   +48 22 615 50 12       1
# 190                                      +48 226649720       1
# 189                                          228569935       1
# 188                                   +48 22 872 27 22       1
# 187                                       +48225771760       1
# 186                                       22 405 39 51       1
# 185                                     +48 22 7372454       1
# 184                                          882195882       1
# 183                                   +48 22 612 01 38       1
# 182                                   +48 22 205 81 43       1
# 181                                      +48 604469317       1
# 180                                   +48 22 825 04 71       1
# 179                                   +48 22 250 00 54       1
# 178                                          226320316       1
# 177                                          606446296       1
# 176                                    +48 602 785 695       1
# 201                                    (+48)22/6578011       1
# 203                                       +48227563291       1
# 174                                       +48227372454       1
# 204                                     +48 22 3718394       1
# 229                                   +48 22 233 10 00       1
# 228                                      +48 227202555       1
# 227                                       22 782 75 90       1
# 226                                    +48 668 134 409       1
# 225                                   +48 22 894 21 21       1
# 224                                      +48 226412460       1
# 223                                     +48 22 8289901       1
# 222                                       +48226965000       1
# 221                                       +48256822274       1
# 220                                       +48468564060       1
# 219                                     +48 22 7253048       1
# 218                                   +48 22 301 19 09       1
# 217                                       +48228263008       1
# 216                                     +48 22 2519294       1
# 215                                   +48 46 855 44 67       1
# 214                  +48 728 415 296 / +48 784 652 269       1
# 213                                    +48 504 309 059       1
# 212                                       22 364 15 63       1
# 211                                       +48221605000       1
# 210                                   +48 60 277 39 97       1
# 209                                    +48 570 801 340       1
# 208                                    +48 509 398 501       1
# 207                                     +48-25-7585200       1
# 206                                            orchard       1
# 205                                    +48 530 901 194       1
# 175                                    +4822 504 20 00       1
# 173                                   +48 22 412 99 12       1
# 117                                       22 636 47 74       1
# 144                                          226626780       1
# 142                                    +48 505 291 198       1
# 141                                       22 619 23 71       1
# 140                                       +48227547272       1
# 139                                       22 443 36 77       1
# 138                                    +48 508 053 431       1
# 137                                      +48 228238636       1
# 136                                   +48 46 855 71 35       1
# 135                                       22 654 04 58       1
# 134                                   +48 46 855 02 28       1
# 133                                   +48 22 55 17 700       1
# 132                          +48222401533;+48516836608       1
# 131                                    +48 510 210 028       1
# 130                             22827 25 92, 228265548       1
# 129                                       +48227598859       1
# 128                                         22 7364870       1
# 127                                    48 22 631 17 82       1
# 126                                       +48227491747       1
# 125                                   +48 22 615 83 64       1
# 124                                       +48236613380       1
# 123                                       22 784 01 24       1
# 122                                    +48 503 040 185       1
# 121                                       +48228186551       1
# 120                                       22 863 50 10       1
# 119                                   +48 22 205 81 45       1
# 118                           602 516 221, 502 612 773       1
# 143                                          509499464       1
# 145                                      +48 227237996       1
# 172                                       +48257582142       1
# 146                                       22 560 37 33       1
# 171                                       +48224000393       1
# 170                                     +48 22 7752368       1
# 169                                       22 774 10 53       1
# 168                                   +48 22 785 05 20       1
# 167                                       +48228702179       1
# 166                                       +48228425813       1
# 165                                       +48800103301       1
# 164                                     +48 22 8281447       1
# 163                    +4822 617 60 25;+4822 617 60 26       1
# 162                                    +48 606 116 267       1
# 161                                      +48 228637981       1
# 160                                     +48 22 4649200       1
# 159                                    +48 502-100-102       1
# 158                                       +48226795859       1
# 157                                    +48 518 739 124       1
# 156                                     +48 22 7588588       1
# 155                                       22 435 96 88       1
# 154                                   +48 22 831 15 37       1
# 153                          +48226285161;+48226256041       1
# 152                                   +48 22 672 80 91       1
# 151                                   +48 22 326 10 10       1
# 150                                       +48221022070       1
# 149                                       +48227231472       1
# 148                                   +48 22 673 58 02       1
# 147                                       22 833 22 05       1
# 232                                       +48512704327       1

# %%
phone[phone.val.str.startswith('+48')]
# Out:
#                                                    val  counts
# 305                                   +48 22 418 00 00       1
# 317                                    +48 517 127 167       1
# 316                                   +48 22 641 93 03       1
# 315                                     +48 22 3532266       1
# 314                                       +48226486630       1
# 312                                   +48 25 759 51 00       1
# 311                                   +48 22 627 11 00       1
# 309                                       +48227221088       1
# 307                                   +48 22 678 17 17       1
# 304                                    +48 261 855 690       1
# 303                                   +48 22 857 34 90       1
# 302                                   +48 46 855 35 47       1
# 301                                     +48 22 6037655       1
# 300                                      +48 228773806       1
# 299                                       +48227762001       1
# 298                                      +48 226310504       1
# 297                                     +48 22 2791400       1
# 296                                   +48 25 757 11 79       1
# 295                                   +48 22 826 30 95       1
# 294                                     +48 22 2578499       1
# 293                                   +48 22 569 71 57       1
# 292                                       +48226121616       1
# 319                                       +48501728895       1
# 321                                    +48 503 086 515       1
# 346                                   +48 22 245 30 32       1
# 344                                    +48 508 954 164       1
# 342                                       +48468564092       1
# 341                                       +48602326874       1
# 340                     +4822 849 14 56;+4822848 48 09       1
# 339                                       +48226145460       1
# 338                                    +48 504 799 161       1
# 335                                     +48 22 6149030       1
# 332                                   +48 22 611 88 88       1
# 329                                   +48 22 825 52 21       1
# 328                                   +48 22 544-26-00       1
# 327                                       +48224582444       1
# 325                          +48226171585;+48226174293       1
# 324                                    +48 603 894 843       1
# 322                  +48 22 750 02 12; +48 506 147 417       1
# 290  +48 22 737 70 70; +48 22 737 71 59; +48 22 703...       1
# 289                                   +48 22 716 51 00       1
# 260                                   +48 46 895 53 19       1
# 258                                       +48227871440       1
# 257                                   +48 22 416 26 11       1
# 256                                     +48 22 3929700       1
# 254                                       +48504949689       1
# 253                                   +48 22 353 20 20       1
# 251                                   +48 22 355 70 00       1
# 249                                       +48227838888       1
# 248                                    +48 693 415 549       1
# 247                                       +48227308100       1
# 245                                       +48503753942       1
# 243                          +48227625365;+48510185277       1
# 240                                   +48 22 849 35 73       1
# 237                                    +48 794 265 385       1
# 236                                   +48 22 675 01 50       1
# 235                                   +48 22 839 04 20       1
# 261                                   +48 46 856 30 30       1
# 288                                   +48 22 592 85 83       1
# 262                                   +48 22 782 30 77       1
# 287                                       +48227867279       1
# 286                                   +48 25 75 75 693       1
# 285                                     +48 22 7567236       1
# 284                                     +48 22 8944200       1
# 283                                       +48227028777       1
# 282                                   +48 25 759 67 15       1
# 279                                     +48 22 5190000       1
# 276                                       +48226182102       1
# 275                                   +48 46 857 13 41       1
# 273                                   +48 22 751 93 94       1
# 271                                     +48-22-6141422       1
# 269                  +48 801 412 414, +48 22 737 50 50       1
# 267                                   +48 22 610 73 09       1
# 266                                     +48 22 7837110       1
# 265                                   +48 22 825 16 50       1
# 263                                       +48227570840       1
# 348                                   +48 25 758 28 14       1
# 349                                   +48 22 514 05 30       1
# 435                                    +48 784 335 558       1
# 432                                       +48788451799       1
# 431                                    +48 663 143 520       1
# 430                                    +48 784 051 110       1
# 429                                    +48 782 755 544       1
# 428                                   +48 22 736 29 00       1
# 427                                     +48 22 8115977       1
# 426                                   +48 22 773 32 81       1
# 425       +48 22 8842080;+48 22 8842081;+48 22 8842082       1
# 424             +48224984646;+48224982626;+48224997764       1
# 423                                   +48 22 403 50 77       1
# 421                                       +48226356314       1
# 419                                   +48 22 448 36 76       1
# 418                                   +48 22 473 59 90       1
# 417                                     +48 22 7742673       1
# 415    +4822 39 27 112;+4822 39 27 113;+4822 39 27 111       1
# 411                                   +48 22 11 000 84       1
# 410                                    +48 608 502 017       1
# 409                                     +48 22 8220920       1
# 434                                   +48 22 415 00 99       1
# 407                                       +48227540650       1
# 437                                   +48 22 784 45 41       1
# 461                                       +48226280295       1
# 460                                    +48 506 852 222       1
# 459                                    +48 510 233 032       1
# 457                                   +48 23 691 04 87       1
# 456                                   +48 22 244 13 13       1
# 455                                    +48 728 639 639       1
# 454                                   +48 22 646 58 55       1
# 453                  +48 607 383 353; +48 22 750 26 28       1
# 451                                       +48225133670       1
# 450                            +48226768287;+226767737       1
# 449                                   +48 22 774 43 44       1
# 448                                   +48 22 737 67 97       1
# 447                                       +48224035555       1
# 446                                   +48 25 759 97 30       1
# 445                 +48 22 464 84 40, +48 506 18 24 99       1
# 444                                       +48225361300       1
# 442                                     +48 22 7679311       1
# 440                  +48 22 649 25 63, +48 505 129 270       1
# 439                                   +48 22 205 81 21       1
# 438                                   +48 22 205 81 22       1
# 408                                    +48 501 516 009       1
# 406                                       +48257593643       1
# 377                                   +48 22 843 58 35       1
# 375                                   +48 22 863 92 52       1
# 373                                   +48 22 611 70 35       1
# 372                                   +48 22 115 05 05       1
# 371                                    +48 261 842 075       1
# 370                                   +48 22 462 85 20       1
# 368                                      +48 505019290       1
# 367                                       +48225721800       1
# 366                                   +48 22 777 62 11       1
# 365                                       +48227231444       1
# 363                                   +48 22 810 33 84       1
# 360                                   +48 22 782 71 08       1
# 359                                    +48 518 130 434       1
# 358                                       +48226293576       1
# 357                                   +48 22 436 56 03       1
# 356                                      +48 225827500       1
# 355                                       +48468578260       1
# 354                                    +48 601 232 962       1
# 351                                       +48226108503       1
# 376                                       +48228720583       1
# 378                                   +48 22 611 34 19       1
# 405                                   +48 22 732 00 36       1
# 403                                   +48 22 531 60 00       1
# 402                                     +48 22 8260363       1
# 401                          +48222560156;+48661433324       1
# 400                                       +48226240800       1
# 399                                   +48 22 373 37 00       1
# 398                  +48 22 501 53 11;+ 48 533 388 588       1
# 396                                       +48690693093       1
# 395                                    +48 501 190 009       1
# 394                                   +48 535 04 50 50       1
# 392                                    +48  22 2113232       1
# 389                                       +48227856583       1
# 387                                    +4822 651 60 98       1
# 386                                   +48 22 123 76 78       1
# 385                                      +48 607552069       1
# 384                                   +48 22 773 61 30       1
# 383                      +4822628 63 30;+4822628 25 86       1
# 382                                    +48 888 942 999       1
# 231                                   +48 603 99 66 66       1
# 86                                        +48227811817       1
# 83                                        +48722311722       1
# 81                                      +48 22 5722500       1
# 80                                        +48224978567       1
# 79                                        +48222176500       1
# 78                                    +48 22 462 83 10       1
# 76   +48228263471;+48228263472;+48228263473;+482282...       1
# 74                                   +48 22 77 33 77 9       1
# 72                                    +48 23 691 05 50       1
# 71                                        +48226794692       1
# 70                                       +48 226215315       1
# 69                                        +48224902025       1
# 68                                        +48224635201       1
# 67                                     +48 506 666 118       1
# 66                                      +48 22 3496100       1
# 65                                    +48 22 487 98 91       1
# 64                                        +48228266318       1
# 63                                        +48228348668       1
# 62                                        +48228112962       1
# 60                                    +48 785 81 82 82       1
# 88                                   +48 023 691 04 27       1
# 113                                    +48 881 406 406       1
# 112                                   +48 22 649 14 40       1
# 110                                       +48693077633       1
# 108                                   +48 25 757 78 93       1
# 107                                   +48 22 258 39 59       1
# 106                                   +48 48 661 43 37       1
# 104                                   +48 22 88 777 37       1
# 103                                    +48 797 901 201       1
# 102                                   +48 22 217 31 20       1
# 101                                       +48227284262       1
# 100             +48228895012;+48228895013;+48226765380       1
# 96                                    +48 22 649 99 81       1
# 95                       +4822629 34 46;+4822622 47 97       1
# 94                                    +48 22 405 82 90       1
# 92                                    +48 22 407 20 03       1
# 91                                        +48226141190       1
# 90                                        +48226489818       1
# 59                                      +48 22 7568056       1
# 57                       +48 22 6203394;+48 22 6202785       1
# 28                                     +48 503 493 778       1
# 26                                     +48 22 558 1234       1
# 20                                    +48 22 812 65 17       1
# 19                                        +48500021342       1
# 18                                    +48 22 833 56 60       1
# 17   +48226253410;+48226253368;+48226221350;+482262...       1
# 16                                    +48 22 51 66 100       1
# 14              +48226213453;+48226215575;+48226215954       1
# 12                                    +48 22 349 23 96       1
# 11                                        +48501040903       1
# 10                        +48 22 6143866;+48 501040780       1
# 8                                     +48 22 825 36 70       1
# 7                                       +48 22 6142239       1
# 6                                         +48227534010       1
# 5                                     +48 22 810 02 57       1
# 4                                        +48 728827546       1
# 3                                     +48 22 408 20 20       1
# 27                                        +48515038839       1
# 29                                        +48227836604       1
# 56                                        +48227231252       1
# 30                                     +48 261 879 505       1
# 54                                    +48 22 582 99 00       1
# 51                                      +48 22 4033442       1
# 50                                        +48506859954       1
# 48                                    +48 22 813 10 22       1
# 47                                        +48226120023       1
# 44                                       +48 886886856       1
# 43                                    +48 22 756 22 18       1
# 41                                    +48 519 00 00 14       1
# 39                                        +48501701442       1
# 38                                        +48570600507       1
# 37                                        +48226490503       1
# 33                                     +48 789 495 410       1
# 32                                    +48 22 44 30 400       1
# 230                                   +48 22 844 56 96       1
# 202                                   +48 22 757 00 73       1
# 200                                       +48224259524       1
# 198       +4822849 64 14;+4822849 14 06;+4822849 47 30       1
# 197                                      +48 228142179       1
# 196                                   +48 22 679 84 69       1
# 195                                   +48 22 678 84 76       1
# 194                                     +48-22-6757186       1
# 193                                   +48 22 811 92 84       1
# 191                                   +48 22 615 50 12       1
# 190                                      +48 226649720       1
# 188                                   +48 22 872 27 22       1
# 187                                       +48225771760       1
# 185                                     +48 22 7372454       1
# 183                                   +48 22 612 01 38       1
# 182                                   +48 22 205 81 43       1
# 181                                      +48 604469317       1
# 180                                   +48 22 825 04 71       1
# 179                                   +48 22 250 00 54       1
# 176                                    +48 602 785 695       1
# 203                                       +48227563291       1
# 174                                       +48227372454       1
# 204                                     +48 22 3718394       1
# 229                                   +48 22 233 10 00       1
# 228                                      +48 227202555       1
# 226                                    +48 668 134 409       1
# 225                                   +48 22 894 21 21       1
# 224                                      +48 226412460       1
# 223                                     +48 22 8289901       1
# 222                                       +48226965000       1
# 221                                       +48256822274       1
# 220                                       +48468564060       1
# 219                                     +48 22 7253048       1
# 218                                   +48 22 301 19 09       1
# 217                                       +48228263008       1
# 216                                     +48 22 2519294       1
# 215                                   +48 46 855 44 67       1
# 214                  +48 728 415 296 / +48 784 652 269       1
# 213                                    +48 504 309 059       1
# 211                                       +48221605000       1
# 210                                   +48 60 277 39 97       1
# 209                                    +48 570 801 340       1
# 208                                    +48 509 398 501       1
# 207                                     +48-25-7585200       1
# 205                                    +48 530 901 194       1
# 175                                    +4822 504 20 00       1
# 173                                   +48 22 412 99 12       1
# 142                                    +48 505 291 198       1
# 140                                       +48227547272       1
# 138                                    +48 508 053 431       1
# 137                                      +48 228238636       1
# 136                                   +48 46 855 71 35       1
# 134                                   +48 46 855 02 28       1
# 133                                   +48 22 55 17 700       1
# 132                          +48222401533;+48516836608       1
# 131                                    +48 510 210 028       1
# 129                                       +48227598859       1
# 126                                       +48227491747       1
# 125                                   +48 22 615 83 64       1
# 124                                       +48236613380       1
# 122                                    +48 503 040 185       1
# 121                                       +48228186551       1
# 119                                   +48 22 205 81 45       1
# 145                                      +48 227237996       1
# 172                                       +48257582142       1
# 171                                       +48224000393       1
# 170                                     +48 22 7752368       1
# 168                                   +48 22 785 05 20       1
# 167                                       +48228702179       1
# 166                                       +48228425813       1
# 165                                       +48800103301       1
# 164                                     +48 22 8281447       1
# 163                    +4822 617 60 25;+4822 617 60 26       1
# 162                                    +48 606 116 267       1
# 161                                      +48 228637981       1
# 160                                     +48 22 4649200       1
# 159                                    +48 502-100-102       1
# 158                                       +48226795859       1
# 157                                    +48 518 739 124       1
# 156                                     +48 22 7588588       1
# 154                                   +48 22 831 15 37       1
# 153                          +48226285161;+48226256041       1
# 152                                   +48 22 672 80 91       1
# 151                                   +48 22 326 10 10       1
# 150                                       +48221022070       1
# 149                                       +48227231472       1
# 148                                   +48 22 673 58 02       1
# 232                                       +48512704327       1

# %% [markdown]
# After looking into the attributes with the most counts I did not find any problems with the usual street and postcode.
#
# The phone numbers can use some cleaning and I will do that.
#
# Looking into the amenity 'key' I noticed that there are many custom entries that do not appear at the wiky for this 'key'.
#
# The idea is to use the json provided by the [API](https://taginfo.openstreetmap.org/taginfo/apidoc#api_4_key_values) with the most common values and filter the values of my map based on their number of occurences or the existence of a wiki:

# %%
#Find amenity
osm_file = 'warsaw_poland_sample_k=2.osm'
types = find(osm_file, 'amenity')

vals_amenity = pd.DataFrame({'val':types.keys(), 'counts': types.values()}, columns=['val','counts']).sort_values(by='counts', ascending=False)

# %%
vals_amenity
# Out:
#                              val  counts
# 44                       parking    4277
# 84                         bench    1015
# 24                  waste_basket     752
# 70                    restaurant     747
# 72                           atm     517
# 59                 parking_space     506
# 22                        school     486
# 15                      pharmacy     422
# 56                     fast_food     388
# 25                          bank     385
# 94               bicycle_parking     321
# 118                         cafe     272
# 26              place_of_worship     264
# 20                          fuel     254
# 16                  kindergarten     234
# 124                      shelter     227
# 57                      post_box     170
# 102                      doctors     160
# 8                    post_office     145
# 137              vending_machine     143
# 110              public_building     140
# 66                bicycle_rental     132
# 113                     car_wash     129
# 30              parking_entrance     128
# 41                       library     119
# 60                           pub     103
# 10                       toilets     101
# 122                 fire_station      99
# 101                      dentist      97
# 77                     recycling      91
# 46                      grit_bin      84
# 54                      fountain      81
# 28                           bar      77
# 90                      hospital      65
# 12                        police      59
# 52                    veterinary      58
# 7                        embassy      57
# 108                 citymap_post      57
# 36                waste_disposal      56
# 0                           taxi      55
# 31                    university      55
# 96                drinking_water      53
# 78                   marketplace      51
# 13                      townhall      46
# 6                         clinic      37
# 121                  arts_centre      35
# 21                        beater      32
# 34                     enclosing      31
# 123                      theatre      31
# 75                   bus_station      28
# 5                social_facility      25
# 73                     nightclub      23
# 111                       cinema      20
# 9               bureau_de_change      20
# 114                    telephone      17
# 67                    courthouse      16
# 14              community_centre      16
# 129                    ice_cream      12
# 115                hunting_stand      10
# 71                ferry_terminal       9
# 116                    childcare       8
# 40                         house       8
# 51                         clock       8
# 117              language_school       7
# 136                swimming_pool       7
# 37                    grave_yard       7
# 92                    car_rental       7
# 128               driving_school       6
# 42                       college       6
# 2                         office       5
# 88                compressed_air       5
# 50                    food_court       5
# 99                           gym       5
# 11        bicycle_repair_station       5
# 61                        studio       4
# 49              charging_station       4
# 65                    biergarten       4
# 33                       brothel       4
# 19                        prison       3
# 82                  nursing_home       3
# 48                      check_in       3
# 85             funerary_services       2
# 17               coworking_space       2
# 91            vehicle_inspection       2
# 93                    parcel_box       2
# 79                animal_shelter       2
# 63                     baby_care       2
# 133              aviation_school       2
# 53                       factory       2
# 132                 estate_agent       2
# 43                        lawyer       2
# 125                    monastery       2
# 1                           dojo       2
# 105                          bbq       2
# 64                        notary       2
# 135                         wifi       2
# 112             municipal_police       1
# 119                    insurance       1
# 134              animal_boarding       1
# 4          Kancelaria_Notarialna       1
# 120                 martial_arts       1
# 3                          photo       1
# 131              retirement_home       1
# 130                        grave       1
# 126                      customs       1
# 127                  film_studio       1
# 109                 game_feeding       1
# 89                  movie_studio       1
# 107                 concert_hall       1
# 106              register_office       1
# 38                cooking_school       1
# 45                     billboard       1
# 47                stock_exchange       1
# 35                      security       1
# 55                      atm;bank       1
# 32                   crematorium       1
# 58                  funeral_home       1
# 29       City Information System       1
# 62             exhibition_centre       1
# 27   Cities Lighting Consultants       1
# 68            lokal_do_wynajęcia       1
# 23                      forester       1
# 74                      cityhall       1
# 76               vehicle_control       1
# 80                luggage_locker       1
# 81                    Janczewice       1
# 83                       hospice       1
# 18                   laundry_box       1
# 86                dancing_school       1
# 87                         fence       1
# 39                air_compressor       1
# 95                     Zwrotnica       1
# 97                           yes       1
# 98                     publisher       1
# 100            employment_agency       1
# 103                     ministry       1
# 104               border_control       1
# 69            motorcycle_parking       1

# %%
vals_amenity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138 entries, 44 to 69
# Data columns (total 2 columns):
# val       138 non-null object
# counts    138 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# Get the json from the taginfo API for commonly used amenity values

# %%
#https://stackoverflow.com/questions/12965203/how-to-get-json-from-webpage-into-python-script
url = "https://taginfo.openstreetmap.org/api/4/key/values?key=amenity&in_wiki=true&filter=all&lang=en&lang=pl&sortname=count&sortorder=desc&rp=14&qtype=value&format=json_pretty"
response = urllib.urlopen(url)
amenity = pd.DataFrame(json.loads(response.read()))

data_amenity = pd.DataFrame(list(amenity.data))

# %%
data_amenity

# %%
#https://stackoverflow.com/infoquestions/15325182/how-to-filter-rows-in-pandas-by-regex
data_amenity[(data_amenity.in_wiki==True) & (data_amenity.value.str.contains('hotel'))]
# Out:
#       count description  fraction in_wiki       value
# 124     862                0.0001    True  love_hotel
# 1358      5                0.0000    True       hotel

# %%
def audit_type(val_to_audit, expected):
    '''Receives series of values to audit and the list of expected values and returns set
       of values not in expected'''
    types = set()
    for val in val_to_audit:
        if val not in expected:
            types.add(val)
    return types

# %%
#Audit amenity with occ occurences in OSM db
occ=1

val_to_audit= list(vals_amenity.val)
expected = list((data_amenity[(data_amenity['count'] >= occ)]).value)
audit_amenity = audit_type(val_to_audit, expected)

# %%
audit_amenity,len(audit_amenity)
# Out:
# (set(), 0)

# %% [markdown]
# There are 0 entries that do not exist in the OSM Database
#
# Let's try this with entries that have more than 5 occurences in the OSM Database

# %%
#Audit amenity with k occurences in OSM db
occ=5

val_to_audit= list(vals_amenity.val)
expected = list((data_amenity[(data_amenity['count'] >= occ)]).value)
audit_amenity = audit_type(val_to_audit, expected)

# %%
audit_amenity,len(audit_amenity)
# Out:
# ({'Cities Lighting Consultants',
#   'City Information System',
#   'Janczewice',
#   'Kancelaria_Notarialna',
#   'Zwrotnica',
#   'air_compressor',
#   'aviation_school',
#   'cityhall',
#   'fence',
#   'film_studio',
#   'laundry_box',
#   u'lokal_do_wynaj\u0119cia',
#   'movie_studio',
#   'municipal_police',
#   'vehicle_control'},
#  15)

# %% [markdown]
# 15 entries.
#
# What will happen only the entries with wiki_entries and 10 occurences

# %%
#Audit amenity with k occurences in OSM db
occ=10

val_to_audit= list(vals_amenity.val)
expected = list((data_amenity[(data_amenity['count'] >= occ) & (data_amenity.in_wiki==True) ]).value)
audit_amenity = audit_type(val_to_audit, expected)

# %%
audit_amenity, len(audit_amenity)
# Out:
# ({'Cities Lighting Consultants',
#   'City Information System',
#   'Janczewice',
#   'Kancelaria_Notarialna',
#   'Zwrotnica',
#   'air_compressor',
#   'atm;bank',
#   'aviation_school',
#   'baby_care',
#   'beater',
#   'billboard',
#   'border_control',
#   'check_in',
#   'cityhall',
#   'cooking_school',
#   'employment_agency',
#   'enclosing',
#   'estate_agent',
#   'factory',
#   'fence',
#   'film_studio',
#   'forester',
#   'funeral_home',
#   'funerary_services',
#   'grave',
#   'house',
#   'insurance',
#   'laundry_box',
#   'lawyer',
#   u'lokal_do_wynaj\u0119cia',
#   'luggage_locker',
#   'martial_arts',
#   'ministry',
#   'movie_studio',
#   'municipal_police',
#   'notary',
#   'parcel_box',
#   'photo',
#   'publisher',
#   'security',
#   'stock_exchange',
#   'vehicle_control',
#   'wifi',
#   'yes'},
#  44)

# %% [markdown]
# 44 - How to handle this?
#
# Let's see if we can find equivalent meanings in the OSM db and map them.

# %%
# Looking for baby_care

data_amenity[(data_amenity.in_wiki==True) & ((data_amenity.value.str.contains('baby')) 
                                          | (data_amenity.value.str.contains('child'))
                                          | (data_amenity.value.str.contains('kinder')))]
# Out:
#       count                                        description  fraction in_wiki         value
# 14   179214  A place for looking after preschool children a...    0.0160    True  kindergarten
# 68     9232  Describes a place where children of different ...    0.0008    True     childcare
# 151     398                                      pl=Okno życia    0.0000    True    baby_hatch

# %% [markdown]
# Does not really make any sense to change that..

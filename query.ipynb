# %%
from sqlite3 import dbapi2 as sq3
import os
import pandas as pd
import urllib, json
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:98% !important; }</style>"))
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)
pd.set_option('display.notebook_repr_html', True)
# Out:
# <style>.container { width:98% !important; }</style>

# %% [markdown]
# ### Create the database

# %%
ourschema = '''
DROP TABLE IF EXISTS 'nodes';
DROP TABLE IF EXISTS 'nodes_tags';
DROP TABLE IF EXISTS 'ways';
DROP TABLE IF EXISTS 'ways_tags';
DROP TABLE IF EXISTS 'ways_nodes';
CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);

CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);

CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);'''

# %%
PATHSTART="."
def get_db(dbfile):
    sqlite_db = sq3.connect(os.path.join(PATHSTART, dbfile))
    return sqlite_db

# %% [markdown]
# Sqlite is a text or memory based database. Connect and get a DBAPI2 connection.

# %% [markdown]
# Drop tables if they exist and create them.

# %%
def init_db(dbfile, schema):
    """Creates the database tables."""
    db = get_db(dbfile)
    db.cursor().executescript(schema)
    db.commit()
    return db

# %% [markdown]
# Use Pandas to read in the data

# %%
#Initiate the Database - 
db=init_db("Warsaw_Poland.db", ourschema)

#Read the CSV's and populate with Pandas(if_exist=replace istead of append solved the IS NULL error)
for f in os.listdir('./CSV_Files/'):
    df=pd.read_csv("./CSV_Files/{}".format(f), sep=',', encoding='utf-8')
    
    df.to_sql(f[14:-4], db, if_exists="replace", index=False, schema=ourschema)

# %%
db = get_db('Warsaw_Poland.db')

# %%
def make_query(sel):
    c=db.cursor().execute(sel)
    return c.fetchall()

# %%
cont_cols = [e[1] for e in make_query("PRAGMA table_info(ways_tags);")]
cont_cols
# Out:
# [u'id', u'key', u'value', u'type']

# %%
def make_frame(list_of_tuples, legend=cont_cols):
    framelist=[]
    for i, cname in enumerate(legend):
        framelist.append((cname,[e[i] for e in list_of_tuples]))
    return pd.DataFrame.from_items(framelist)

# %% [markdown]
# ### All ways_tags keys and value counts

# %%
columns = ' DISTINCT key,' + ' count(key)'
query = 'SELECT '+ columns + ' FROM ways_tags GROUP BY key ORDER BY count(key) DESC'.format(columns)
pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])
# Out:
#                    DISTINCT key   count(key)
# 0                      building       324088
# 1                       highway       175659
# 2                   housenumber       139472
# 3                          city       138127
# 4                        street       137226
# 5                      postcode       131824
# 6                          addr       116319
# 7                     city:simc       102973
# 8                 street:sym_ul        97547
# 9                          name        67942
# 10                      landuse        62813
# 11                       source        42225
# 12                      surface        38457
# 13                     maxspeed        25019
# 14                       oneway        22479
# 15                        lanes        17226
# 16                      service        15224
# 17                      barrier        14643
# 18                      natural        14330
# 19                          ref        14296
# 20                      amenity        13314
# 21                       access        10021
# 22                          lit         9559
# 23                       levels         9538
# 24                    tracktype         8698
# 25                      leisure         6619
# 26                  maxaxleload         6443
# 27                     geometry         6105
# 28                      railway         5478
# 29                        layer         5449
# 30                       height         5354
# 31                     material         4987
# 32                      voltage         4647
# 33                       colour         4546
# 34                      bicycle         4425
# 35                     waterway         4280
# 36                        gauge         4198
# 37                         foot         4120
# 38                  electrified         4089
# 39                        place         4066
# 40                      footway         3956
# 41                     boundary         3920
# 42                  conditional         3706
# 43                    wikipedia         3592
# 44                     wikidata         3459
# 45                         area         3301
# 46                          bus         3280
# 47                      parking         3245
# 48              maxaxleload:url         3213
# 49                       bridge         3146
# 50                    frequency         3113
# 51                         part         2825
# 52                        water         2814
# 53             public_transport         2425
# 54                        shape         2410
# 55                       tunnel         2268
# 56                      network         2150
# 57                        power         2006
# 58                     operator         1944
# 59                         shop         1864
# 60                     cemetery         1856
# 61                      website         1823
# 62                     junction         1743
# 63                         note         1727
# 64                    maxweight         1603
# 65                      int_ref         1582
# 66              hgv:conditional         1523
# 67                   smoothness         1481
# 68                        sport         1401
# 69                       cables         1338
# 70                        usage         1263
# 71                motor_vehicle         1213
# 72                   min_height         1129
# 73                        horse         1072
# 74                        phone         1061
# 75                     man_made         1053
# 76                          fee         1028
# 77                          hgv         1023
# 78                        width         1010
# 79                      trailer          980
# 80                      shelter          971
# 81                        bench          964
# 82                      forward          951
# 83                     backward          922
# 84                     cycleway          901
# 85                     crossing          878
# 86                     capacity          845
# 87                 construction          841
# 88                     proposed          839
# 89                opening_hours          838
# 90                   wheelchair          801
# 91        maxgcweightrating:hgv          797
# 92                      covered          794
# 93                      country          793
# 94                   segregated          761
# 95                   fence_type          760
# 96                  category:pl          714
# 97                     class:pl          714
# 98                     old_name          713
# 99                     alt_name          702
# 100                     old_ref          670
# 101                    religion          613
# 102                       email          578
# 103                  created_by          571
# 104                denomination          565
# 105            trail_visibility          545
# 106                buildingpart          506
# 107                   motorroad          504
# 108                     incline          483
# 109                          pl          468
# 110                   park_ride          463
# 111                         psv          445
# 112                agricultural          437
# 113                   min_level          434
# 114                        toll          421
# 115                    sidewalk          413
# 116                          en          402
# 117               lanes:forward          401
# 118                 destination          400
# 119                  supervised          399
# 120              lanes:backward          397
# 121                        simc          393
# 122                         fax          389
# 123                   placement          382
# 124                   housename          381
# 125                       fixme          377
# 126                  short_name          369
# 127                         ele          360
# 128                   leaf_type          345
# 129             slope:direction          339
# 130                   maxheight          332
# 131                     tourism          304
# 132                 orientation          300
# 133                    location          293
# 134                       level          287
# 135                  embankment          283
# 136                    toll:url          277
# 137                      noexit          276
# 138                   track_ref          257
# 139               official_name          242
# 140                          de          240
# 141               protect_class          233
# 142                    motorcar          226
# 143                  substation          224
# 144                        tram          220
# 145                     wetland          218
# 146                    historic          210
# 147             verticalpassage          210
# 148            protection_title          208
# 149  verticalpassage:floorrange          206
# 150                     aeroway          205
# 151                    disabled          198
# 152             traffic_calming          193
# 153                          ru          190
# 154                shelter_type          184
# 155                       brand          174
# 156            maxspeed:forward          159
# 157             passenger_lines          156
# 158                 maxgcweight          154
# 159           maxspeed:backward          154
# 160                        type          147
# 161                     cuisine          146
# 162                        boat          145
# 163                    end_date          145
# 164                  motorcycle          144
# 165                   sac_scale          142
# 166                         gid          140
# 167                  kodinspire          140
# 168                      indoor          136
# 169           maxgcweightrating          133
# 170                      tracks          125
# 171                       is_in          124
# 172                        line          118
# 173                      office          117
# 174                       scale          117
# 175                       train          116
# 176                         bin          113
# 177                       right          113
# 178                    loc_name          109
# 179                     vehicle          109
# 180              tactile_paving          103
# 181                        wall          103
# 182                 description          100
# 183                   octane_95           97
# 184                 designation           96
# 185                      diesel           96
# 186                        ulic           92
# 187                   octane_98           91
# 188                     cutting           90
# 189                   direction           90
# 190                      animal           88
# 191                      noname           82
# 192                         ski           82
# 193                         ztm           82
# 194                         lpg           79
# 195                          es           76
# 196                        left           74
# 197                       wires           73
# 198                      parent           69
# 199                   emergency           68
# 200                  signal_box           68
# 201                     size:ha           66
# 202                  snowmobile           66
# 203              reservoir_type           63
# 204                     smoking           63
# 205                   SITE_CODE           62
# 206                  diplomatic           62
# 207                 established           62
# 208                       women           59
# 209                    backrest           55
# 210                  attraction           54
# 211                    int_name           53
# 212                     deanery           52
# 213             internet_access           52
# 214                     diocese           51
# 215                       goods           51
# 216                scale:uphill           50
# 217                       grade           49
# 218                        kerb           49
# 219                     bollard           48
# 220                         use           48
# 221               interpolation           47
# 222                   ref:lanes           47
# 223                     disused           46
# 224                    handrail           46
# 225                   highspeed           46
# 226                          uk           46
# 227                        room           44
# 228                  balrog-kun           43
# 229                    heritage           43
# 230                         url           43
# 231                        rail           42
# 232                      symbol           42
# 233                          fr           39
# 234                         nid           39
# 235                  HGV_diesel           38
# 236                     mooring           38
# 237        backward:conditional           36
# 238                  scale:imba           35
# 239                colour:lanes           34
# 240                          eo           33
# 241            construction_end           32
# 242                  denotation           32
# 243                       image           32
# 244               int_ref:lanes           32
# 245       maxgvweightrating:hgv           31
# 246                         lcn           30
# 247                  leaf_cycle           30
# 248                bus:backward           28
# 249                  overtaking           28
# ..                          ...          ...
# 456                          et            3
# 457                   full_name            3
# 458               gas_insulated            3
# 459                        golf            3
# 460                   highway_1            3
# 461                          ko            3
# 462                        link            3
# 463          marked_trail_green            3
# 464                      meadow            3
# 465             mini_roundabout            3
# 466              miniroundabout            3
# 467                mobile_phone            3
# 468                   motorboat            3
# 469                      name_2            3
# 470                          no            3
# 471                       notes            3
# 472                 old_landuse            3
# 473                        pfcc            3
# 474                  place_name            3
# 475                    position            3
# 476                     private            3
# 477                      routex            3
# 478                 second_hand            3
# 479                      shop_1            3
# 480                        stub            3
# 481                       style            3
# 482                     towards            3
# 483                     twitter            3
# 484                     uic_ref            3
# 485                       voice            3
# 486                 _SITE_CODE_            2
# 487                   aerialway            2
# 488              animal_keeping            2
# 489                         bag            2
# 490                          bg            2
# 491                bicycle_road            2
# 492                    caravans            2
# 493                      center            2
# 494                     checked            2
# 495                closest_town            2
# 496                       coins            2
# 497            collection_times            2
# 498            community_centre            2
# 499                          da            2
# 500                 debit_cards            2
# 501                     display            2
# 502              drinking_water            2
# 503                    entrance            2
# 504                       fence            2
# 505                       hight            2
# 506                        iata            2
# 507                         ilt            2
# 508          lane:left:parallel            2
# 509             license_classes            2
# 510               living_street            2
# 511                   lock_name            2
# 512                     luggage            2
# 513                     maestro            2
# 514                maxgcwrating            2
# 515                microbrewery            2
# 516                   min_heigh            2
# 517                     no_name            2
# 518                      nudism            2
# 519                   octane_91            2
# 520                    old_shop            2
# 521                     outline            2
# 522                     plastic            2
# 523          public_transport_1            2
# 524                      rating            2
# 525                   recording            2
# 526                 ref:forward            2
# 527                      rental            2
# 528                    resource            2
# 529                        stay            2
# 530                     storage            2
# 531                     support            2
# 532                   surface_1            2
# 533                surveillance            2
# 534                       tents            2
# 535                        todo            2
# 536                      tracer            2
# 537                      usługi            2
# 538                     vending            2
# 539                  visa_debit            2
# 540               visa_electron            2
# 541                   wall_type            2
# 542                     western            2
# 543                   zoomlevel            2
# 544                        170a            1
# 545                        1_25            1
# 546                        1_50            1
# 547                           2            1
# 548                  Kancelaria            1
# 549                      Nowych            1
# 550                           a            1
# 551                   abandoned            1
# 552                         acc            1
# 553                    access_1            1
# 554      accor_ticket_acceptant            1
# 555               addr:postcode            1
# 556                     address            1
# 557                    adoption            1
# 558                   aerodrome            1
# 559                 air_quality            1
# 560                     alcohol            1
# 561                altered_name            1
# 562                 alternative            1
# 563                   amenity_1            1
# 564                   amenity_2            1
# 565              animal_shelter            1
# 566                     atm_ref            1
# 567                      autism            1
# 568                        baby            1
# 569                    bancomat            1
# 570                        beds            1
# 571                      biogas            1
# 572                         biu            1
# 573                       books            1
# 574                    bridge_1            1
# 575             building:levels            1
# 576                    car_wash            1
# 577                   cardboard            1
# 578                     cartons            1
# 579       colour:lanes:backward            1
# 580                   computers            1
# 581                      county            1
# 582                credit_cards            1
# 583                      crop_1            1
# 584                      crop_2            1
# 585                      crop_3            1
# 586                      crop_4            1
# 587                crossing_box            1
# 588                  demolished            1
# 589                   dentistry            1
# 590                  difficulty            1
# 591                    discount            1
# 592                         dog            1
# 593                        door            1
# 594                      dormer            1
# 595                    drive_in            1
# 596                    duration            1
# 597                         e10            1
# 598                         e85            1
# 599       electrical_appliances            1
# 600            electrical_items            1
# 601                     endline            1
# 602                   est_width            1
# 603                     ethanol            1
# 604                     factory            1
# 605                       ferry            1
# 606                   fireplace            1
# 607                     fishing            1
# 608                        full            1
# 609                    function            1
# 610               glass_bottles            1
# 611                  government            1
# 612                    grooming            1
# 613                 guest_house            1
# 614                      hamlet            1
# 615                     height1            1
# 616                hgv:backward            1
# 617                       hgv_1            1
# 618                        hide            1
# 619                  historical            1
# 620                       hotel            1
# 621                housename:de            1
# 622                          id            1
# 623                   instagram            1
# 624            int_ref:backward            1
# 625                          kr            1
# 626                   leisure_1            1
# 627                   leisure_2            1
# 628                        lock            1
# 629                     lottery            1
# 630                   magazines            1
# 631                   max_level            1
# 632                  military_1            1
# 633                    minspeed            1
# 634                     name:uk            1
# 635                   newspaper            1
# 636                   occupancy            1
# 637                   octane_92            1
# 638                old_building            1
# 639                 old_highway            1
# 640                 old_surface            1
# 641                    openfire            1
# 642                opening_date            1
# 643                     organic            1
# 644     output:battery_charging            1
# 645             output:cold_air            1
# 646           output:cold_water            1
# 647       output:compressed_air            1
# 648              output:hot_air            1
# 649                output:steam            1
# 650               output:vacuum            1
# 651             paper_packaging            1
# 652              parcel_mail_in            1
# 653               parcel_pickup            1
# 654                      patron            1
# 655                      phone2            1
# 656                     phone_1            1
# 657                   pinterest            1
# 658                     planned            1
# 659                       plant            1
# 660             plastic_bottles            1
# 661           plastic_packaging            1
# 662                      prefix            1
# 663                  psychiatry            1
# 664               psychotherapy            1
# 665           receiving_country            1
# 666                ref:backward            1
# 667           ref:lanes:forward            1
# 668                      render            1
# 669                   rightline            1
# 670                 roof:height            1
# 671                        ruin            1
# 672                      school            1
# 673             sending_country            1
# 674                    services            1
# 675                    shooting            1
# 676                      shrine            1
# 677                  sognal_box            1
# 678                  speciality            1
# 679                     species            1
# 680                     sport_1            1
# 681                   startline            1
# 682                   stop_line            1
# 683                      studio            1
# 684                 subdistrict            1
# 685                     subtype            1
# 686                      subway            1
# 687                        surf            1
# 688                      target            1
# 689                    teaching            1
# 690                       theme            1
# 691                 tourist_bus            1
# 692                       trade            1
# 693                    training            1
# 694                       ulica            1
# 695                      unisex            1
# 696                    uuk_spec            1
# 697                       vegan            1
# 698                  vegetarian            1
# 699                  visibility            1
# 700                      volume            1
# 701        water_characteristic            1
# 702               wayside_cross            1
# 703                        wifi            1
# 704        year_of_construction            1
# 705                          zh            1
#
# [706 rows x 2 columns]

# %%
columns = ' ways.user'  
query = 'SELECT '+ columns +\
            ' FROM ways, ways_tags, \
            
            (SELECT DISTINCT user, value, count(value) as ct\
            FROM ways, ways_tags\
        WHERE ways.id=ways_tags.id\
        AND key="building"\
        GROUP BY value) as sbq\
        WHERE ways.id=ways_tags.id\
        AND ct<=10\
'.format(columns)

pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-189d1eaec9f8> in <module>()
#       2 query = 'SELECT '+ columns +            ' FROM ways, ways_tags,             (SELECT DISTINCT value, count(value) as ct FROM ways_tags WHERE key="building" GROUP BY value) as sbq        WHERE ways.id=ways_tags.id        AND ct<=10        GROUP BY ways.user        ORDER BY ways.user DESC'.format(columns)
#       3
# ----> 4 pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])
#
# <ipython-input-7-6395480f4af4> in make_query(sel)
#       1 def make_query(sel):
# ----> 2     c=db.cursor().execute(sel)
#       3     return c.fetchall()
#
# KeyboardInterrupt:

# %%
query ='SELECT DISTINCT user, value, count(value) as ct\
            FROM ways, ways_tags\
        WHERE ways.id=ways_tags.id\
        AND key="building"\
        GROUP BY value'
make_query(query)
# Out:
# [(u'KPPSPOTWOCK', u'Budynek Zabytkowy', 1),
#  (u'Alkomat', u'Lokal', 1),
#  (u'WiktorN-import', u'National_Monument', 1),
#  (u'Edyta | Yanosik', u'Plutonowego J\xf3zefa Cie\u0107wierza', 1),
#  (u'korni', u'apartments', 17998),
#  (u'trzebinik', u'barn', 58),
#  (u'kocio', u'belfry', 3),
#  (u'zbyki', u'bridge', 2),
#  (u'hormel', u'bunker', 1),
#  (u'HanyuuFurude', u'cabin', 10),
#  (u'Mala', u'cage', 1),
#  (u'rmikke', u'castle', 2),
#  (u'rmikke', u'cathedral', 1),
#  (u'Mi\u0142y Kuc', u'chapel', 29),
#  (u'Ciemek', u'church', 253),
#  (u'Andrzej3345', u'civ', 1),
#  (u'Deuar', u'civic', 153),
#  (u'Rados\u0142aw Botev', u'commercial', 1580),
#  (u'lemacik', u'conservatory', 4),
#  (u'Mi\u0142y Kuc', u'construction', 196),
#  (u'lemacik', u'container', 6),
#  (u'balrog-kun', u'corridor', 2),
#  (u'd3mol3k', u'cowshed', 4),
#  (u'kocio', u'daycare', 1),
#  (u'Javnik', u'detached', 388),
#  (u'Etua', u'dormitory', 14),
#  (u'masti', u'embassy', 1),
#  (u'Heemskerck', u'empty', 1),
#  (u'Mala', u'enclosing', 20),
#  (u'WiktorN-import', u'farm', 13),
#  (u'Ciemek', u'farm_auxiliary', 930),
#  (u'WiktorN-import', u'fuel', 1),
#  (u'Deuar', u'garage', 1577),
#  (u'Deuar', u'garages', 826),
#  (u'balrog-kun', u'garbage_shed', 1),
#  (u'kilgor', u'greenhouse', 346),
#  (u'Andrzej Talarczyk', u'hangar', 81),
#  (u'lemacik', u'hospital', 115),
#  (u'Rados\u0142aw Botev', u'hotel', 25),
#  (u'Ciemek', u'house', 16457),
#  (u'kocio', u'houseboat', 8),
#  (u'WlaDeQ', u'hut', 55),
#  (u'OpenStreetMap-WP', u'industrial', 946),
#  (u'rosomak', u'iy', 1),
#  (u'Rendi80', u'kindergarten', 79),
#  (u'Deuar', u'kiosk', 9),
#  (u'kocio', u'library', 2),
#  (u'Zibi-importy', u'manufacture', 17),
#  (u'Zbigniew_Czernik', u'military', 1),
#  (u'sir-mapalot', u'monument', 1),
#  (u'balrog-kun', u'museum', 1),
#  (u'kolejo\u017c EP 09', u'no', 10),
#  (u'rmikke', u'palace', 19),
#  (u'wheelmap_visitor', u'parking', 7),
#  (u'kocio', u'part', 4),
#  (u'balrog-kun', u'passage', 1),
#  (u'balrog-kun-imports', u'pharmacy', 1),
#  (u'WiktorN-import', u'presbytery', 1),
#  (u'balrog-kun', u'prison', 4),
#  (u'cedaros', u'public', 116),
#  (u'WiktorN-import', u'restaurant', 1),
#  (u'korni', u'retail', 809),
#  (u'Ciemek', u'roof', 763),
#  (u'Mi\u0142y Kuc', u'ruins', 29),
#  (u'Rendi80', u'school', 546),
#  (u'Deuar', u'service', 402),
#  (u'Deuar', u'shed', 195),
#  (u'AdamekJeden', u'shrine', 3),
#  (u'd3mol3k', u'silo', 3),
#  (u'Tomekg', u'sports_centre', 9),
#  (u'WiktorN-import', u'squat', 2),
#  (u'Andrzej Talarczyk', u'stable', 14),
#  (u'kocio', u'stadium', 4),
#  (u'Deuar', u'stands', 1),
#  (u'grivo', u'static_caravan', 1),
#  (u'cedaros', u'storage_tank', 2),
#  (u'kocio', u'supermarket', 75),
#  (u'kubek_77', u'swimming_pool', 2),
#  (u'rmikke', u'synagogue', 1),
#  (u'WiktorN-import', u'temple', 2),
#  (u'lemacik', u'tent', 2),
#  (u'Vistula228', u'terminal', 3),
#  (u'piotrulos', u'terrace', 1681),
#  (u'balrog-kun', u'tower', 1),
#  (u'cedaros', u'train_station', 52),
#  (u'cedaros', u'transformer_tower', 6),
#  (u'Spokojny!', u'transportation', 39),
#  (u'balrog-kun', u'tribunes', 1),
#  (u'cedaros', u'university', 132),
#  (u'balrog-kun', u'utility', 1),
#  (u'Javnik', u'wall', 2),
#  (u'kilgor', u'warehouse', 156),
#  (u'Ciemek', u'yes', 276760)]

# %% [markdown]
# To do: Delete the keys with values no and group all the entries below 10

# %% [markdown]
# ### Value counts when key=shop

# %%
columns = ' DISTINCT value,' + ' count(value)'
query = 'SELECT '+ columns + '\
            FROM ways_tags\
        WHERE key = "shop"\
        GROUP BY value\
        ORDER BY count(value) DESC'.format(columns)

pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])
# Out:
#             DISTINCT value   count(value)
# 0              supermarket            308
# 1              convenience            253
# 2                    kiosk            180
# 3               car_repair            142
# 4                      car            126
# 5                     mall            106
# 6                      yes             80
# 7                  florist             66
# 8              greengrocer             53
# 9             doityourself             41
# 10                  bakery             37
# 11                 alcohol             36
# 12           garden_centre             35
# 13               furniture             28
# 14                 clothes             23
# 15             hairdresser             21
# 16                 chemist             18
# 17               newsagent             16
# 18           confectionery             15
# 19                 bicycle             13
# 20             electronics             13
# 21                hardware             13
# 22               car_parts             12
# 23                   trade             12
# 24              motorcycle             11
# 25                 butcher             10
# 26                copyshop             10
# 27                  ticket             10
# 28        department_store              9
# 29       funeral_directors              9
# 30                 lottery              9
# 31                   tyres              9
# 32                    farm              7
# 33                     pet              7
# 34                  beauty              6
# 35                   books              6
# 36              stationery              6
# 37           variety_store              6
# 38                      no              5
# 39                  sports              5
# 40            dry_cleaning              4
# 41                 laundry              4
# 42                   shoes              4
# 43                boutique              3
# 44  construction_materials              3
# 45                    deli              3
# 46                 outdoor              3
# 47              pawnbroker              3
# 48            photo_studio              3
# 49               beverages              2
# 50                 curtain              2
# 51                    gift              2
# 52                glaziery              2
# 53                 grocery              2
# 54                 jewelry              2
# 55            mobile_phone              2
# 56                optician              2
# 57                   photo              2
# 58           travel_agency              2
# 59                  vacant              2
# 60    Artykuły_foto,_LOTTO              1
# 61            art_supplies              1
# 62                     bag              1
# 63     bathroom_furnishing              1
# 64               bookmaker              1
# 65                 bridals              1
# 66          car;car_repair              1
# 67               chocolate              1
# 68                computer              1
# 69              electrical              1
# 70                  erotic              1
# 71            estate_agent              1
# 72                   fixme              1
# 73       funerary_services              1
# 74                gambling              1
# 75                 general              1
# 76         heating_systems              1
# 77               herbalist              1
# 78                    hifi              1
# 79               houseware              1
# 80               insurance              1
# 81     interior_decoration              1
# 82                 massage              1
# 83          medical_supply              1
# 84               motorbike              1
# 85                   other              1
# 86                   paint              1
# 87                  pastry              1
# 88               perfumery              1
# 89            photo studio              1
# 90                 pottery              1
# 91           radiotechnics              1
# 92                 seafood              1
# 93             shoe_repair              1
# 94                solarium              1
# 95             supplements              1
# 96                  tailor              1
# 97                    toys              1
# 98                    wine              1
# 99       zoology;wholesale              1

# %% [markdown]
# Who is the uuser(or users) who is making these custom entries

# %%
columns = ' DISTINCT value,' + ' count(value)'
query = 'SELECT '+ columns + '\
            FROM ways_tags\
        WHERE key = "shop"\
        GROUP BY value\
        ORDER BY count(value) DESC'.format(columns)

pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])

# %%
key= '"colour"'
columns = ' DISTINCT value,' + ' count(value)'
query = 'SELECT  {} \
            FROM ways_tags\
        WHERE key = {}\
        GROUP BY value\
        ORDER BY count(value) DESC'.format(columns, key)

pd.DataFrame(make_query(query), columns=[cols for cols in columns.split(',')])
# Out:
#           DISTINCT value   count(value)
# 0                #666666            751
# 1                #dddddd            321
# 2                    red            282
# 3                #999999            265
# 4                #ffffff            244
# 5                #333333            148
# 6                #e9d8c5            119
# 7                #222222            107
# 8                  black             95
# 9                #deeded             87
# 10               #73b1a6             81
# 11               #eeeeee             74
# 12               #e5ceb5             70
# 13               #dedec5             67
# 14                 white             59
# 15               #99cccc             54
# 16               #b4baba             48
# 17               #000000             43
# 18               #555555             43
# 19               #009933             36
# 20               #387ab8             32
# 21               #554f55             32
# 22               #C34DC0             32
# 23                  blue             32
# 24                  gray             32
# 25               #c0c0c0             28
# 26               #bfbfc4             26
# 27               #A9ACA9             25
# 28                 green             25
# 29               #10396f             24
# 30               #f7e8a8             22
# 31               #bfc1c3             21
# 32               #84bcdf             20
# 33               #e37b42             20
# 34               #808080             19
# 35               #919193             19
# 36               #f8e597             19
# 37                  grey             19
# 38               #336699             18
# 39               #3399cc             18
# 40               #DAE3D3             18
# 41               #BF4F51             17
# 42               #a9a9a9             17
# 43               #6B6C71             16
# 44               #70baa3             16
# 45               #f4d9c6             16
# 46               #006600             15
# 47               #777777             15
# 48               #e5dbc7             14
# 49               #e8e7e5             14
# 50                 brown             14
# 51               #303030             13
# 52               #D6B991             13
# 53               #DED5D0             13
# 54               #FFF2CB             13
# 55               #ffffe0             13
# 56               #AEBCB8             12
# 57               #B26539             12
# 58               #b3c2af             12
# 59               #bbbbbb             12
# 60               #d0e2e1             12
# 61               #d9bc91             11
# 62               #082567             10
# 63               #326d83             10
# 64               #5f9ea0             10
# 65               #637780             10
# 66               #C2B280             10
# 67               #202020              9
# 68               #355978              9
# 69               #545250              9
# 70               #87CEEB              9
# 71               #9e817a              9
# 72               #FFFFFF              9
# 73               #a6abaa              9
# 74                yellow              9
# 75               #0027C2              8
# 76               #626667              8
# 77               #6B4642              8
# 78               #707070              8
# 79               #857056              8
# 80               #973c2a              8
# 81               #CA7C4C              8
# 82               #a99c99              8
# 83               #c1a48b              8
# 84               #009900              7
# 85               #2F4D6F              7
# 86               #806060              7
# 87               #999a94              7
# 88               #FFE79E              7
# 89               #bdd4d5              7
# 90               #cd5c5c              7
# 91               #0e375f              6
# 92               #151414              6
# 93               #2e404e              6
# 94               #798998              6
# 95               #888888              6
# 96               #8b8a84              6
# 97               #C0C0C0              6
# 98               #CABC81              6
# 99               #D7D8DA              6
# 100              #d3b692              6
# 101              #e8ddb8              6
# 102              #ebdfce              6
# 103              #ffbe94              6
# 104               silver              6
# 105              #042c61              5
# 106              #61380D              5
# 107              #8B4513              5
# 108              #8a8a8a              5
# 109              #B9B8B6              5
# 110              #BD9460              5
# 111              #CCC7B4              5
# 112              #b0aaa2              5
# 113              #c5aea0              5
# 114              #d4af37              5
# 115              #dde0c8              5
# 116              #ece2be              5
# 117              #233243              4
# 118              #535C52              4
# 119              #5b5b56              4
# 120              #669999              4
# 121              #6EBE9F              4
# 122              #757172              4
# 123              #839099              4
# 124              #8D8C6D              4
# 125              #9cafb3              4
# 126              #A7C0AB              4
# 127              #BCB8B5              4
# 128              #C79A73              4
# 129              #DC9B7B              4
# 130              #FAEAC6              4
# 131              #a1ccb2              4
# 132              #a29c97              4
# 133              #d2d2d2              4
# 134              #d9c5a2              4
# 135              #e8e4e3              4
# 136              #01141c              3
# 137              #224153              3
# 138              #262d2c              3
# 139              #273a5f              3
# 140              #303e3d              3
# 141              #334D70              3
# 142              #400000              3
# 143              #40C080              3
# 144              #575559              3
# 145              #5E6575              3
# 146              #663300              3
# 147              #6785AB              3
# 148              #778899              3
# 149              #79a3d4              3
# 150              #8b8a83              3
# 151              #906030              3
# 152              #A5A28C              3
# 153              #B6CAC9              3
# 154              #BEB7A4              3
# 155              #CABAA0              3
# 156              #CECDCC              3
# 157              #a9adb2              3
# 158              #ca8250              3
# 159              #ccffbc              3
# 160              #ccffcc              3
# 161              #e6cf90              3
# 162              #ead2ec              3
# 163              #f5f5dc              3
# 164              #f8f697              3
# 165              #ffe1a6              3
# 166              #fffbeb              3
# 167               orange              3
# 168            red;white              3
# 169              #006666              2
# 170              #014c4b              2
# 171              #0e1b34              2
# 172              #111111              2
# 173              #4b4d4d              2
# 174              #4d4f4e              2
# 175              #4e3012              2
# 176              #5e5b61              2
# 177              #633f1b              2
# 178              #647887              2
# 179              #677c85              2
# 180              #6DA4DB              2
# 181              #765948              2
# 182              #7F9EB3              2
# 183              #817976              2
# 184              #85867e              2
# 185              #8a887a              2
# 186              #8a8a92              2
# 187              #8e8b7f              2
# 188              #98A897              2
# 189              #99b6b3              2
# 190              #9FC4B9              2
# 191              #9b9693              2
# 192              #9b9794              2
# 193              #9f948b              2
# 194              #A8803B              2
# 195              #A9A9A9              2
# 196              #C4C9CD              2
# 197              #CF9E59              2
# 198              #DED6B1              2
# 199              #EDF3F6              2
# 200              #F2C200              2
# 201              #F2EBE1              2
# 202              #F3B64B              2
# 203              #F5BF69              2
# 204              #FCF2E5              2
# 205              #aacdbc              2
# 206              #ada494              2
# 207              #aecfc5              2
# 208              #c7b59e              2
# 209              #c7c6c4              2
# 210              #e0ffff              2
# 211              #e2deb3              2
# 212              #e3f2f1              2
# 213              #e87e58              2
# 214              #edebdc              2
# 215              #efefef              2
# 216              #f5f5f5              2
# 217         white;;white              2
# 218              #006633              1
# 219              #006699              1
# 220              #008000              1
# 221              #00FF00              1
# 222              #20B2AA              1
# 223              #234f7e              1
# 224              #2E8B57              1
# 225              #2b3d43              1
# 226              #2c4c50              1
# 227              #333945              1
# 228              #444444              1
# 229              #49657A              1
# 230              #4C2816              1
# 231              #4D4C48              1
# 232              #545a56              1
# 233              #577c7c              1
# 234              #5B8BBC              1
# 235              #5a2e2e              1
# 236              #605060              1
# 237              #60646B              1
# 238              #607f9a              1
# 239              #614e40              1
# 240              #61686e              1
# 241              #636E70              1
# 242              #646672              1
# 243              #669f98              1
# 244              #686872              1
# 245              #6A5ACD              1
# 246              #708090              1
# 247              #70acb0              1
# 248              #75706A              1
# 249              #767574              1
# 250              #77766a              1
# 251              #787882              1
# 252              #79563B              1
# 253              #798d8d              1
# 254              #7c473b              1
# 255              #800000              1
# 256              #808000              1
# 257              #809070              1
# 258              #868B91              1
# 259              #875B4F              1
# 260              #87CEFA              1
# 261              #8b8b8a              1
# 262              #93CCE3              1
# 263              #94B3B8              1
# 264              #967c5c              1
# 265              #9B8787              1
# 266              #9bba9b              1
# 267              #9bbbbd              1
# 268              #9c6525              1
# 269              #9c7878              1
# 270              #9fa24f              1
# 271              #A1A5C1              1
# 272              #ABACAF              1
# 273              #AD5B34              1
# 274              #B0B29C              1
# 275              #B77F5A              1
# 276              #B7B6B4              1
# 277              #BBE8FB              1
# 278              #BF644B              1
# 279              #BF8174              1
# 280              #BFADA1              1
# 281              #C3C3C3              1
# 282              #C3C7C6              1
# 283              #C99667              1
# 284              #D0D2CD              1
# 285              #D3D3D3              1
# 286              #DAAD69              1
# 287              #E2D1B3              1
# 288              #E2DACD              1
# 289              #E7D3A7              1
# 290              #E9E9E7              1
# 291              #EEDEC9              1
# 292              #F4D690              1
# 293              #FF0000              1
# 294              #FFC0CB              1
# 295              #FFCC99              1
# 296              #FFF1CA              1
# 297              #adff2f              1
# 298              #b9b0a6              1
# 299              #becfc5              1
# 300              #c58526              1
# 301              #cc3300              1
# 302              #d3d3d3              1
# 303              #d3dbda              1
# 304              #d4a98e              1
# 305              #d4c19f              1
# 306              #e4c25c              1
# 307              #e7e2dc              1
# 308              #ebd6bc              1
# 309              #f8dd97              1
# 310              #f9f8ef              1
# 311              #fae9d3              1
# 312              #ffb4b4              1
# 313              #ffff00              1
# 314                    0              1
# 315  ;;white;white;white              1
# 316               EFDCA9              1
# 317                 gold              1
# 318                 lime              1

# %% [markdown]
# Found an incosistency here with the guidelines

# %% [markdown]
# Let's try to load the whole OSM now

# %% [markdown]
# #### Or populate with SQL INSERT

# %%
ins="""
INSERT INTO candidates (id, first_name, last_name, middle_name, party) \
    VALUES (?,?,?,?,?);
"""
with open("candidates.txt") as fd:
    slines =[l.strip().split('|') for l in fd.readlines()]
    for line in slines[1:]:
        theid, first_name, last_name, middle_name, party = line
        print (theid, first_name, last_name, middle_name, party)
        valstoinsert = (int(theid), first_name, last_name, middle_name, party)
        print (ins, valstoinsert)
        db.cursor().execute(ins, valstoinsert)
